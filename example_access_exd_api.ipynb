# %% [markdown]
# # Access an ASAM ODS EXD-API Plugin

# %% [markdown]
# ## Prepare Python Environment to Access GRPC Service

# %%
try:
    from odsbox.proto import ods_external_data_pb2 as exd
except:
    # first time you need to install dependencies
    # !python -m pip install --upgrade pip
    # !python -m pip install -U odsbox[exd-data]

# %%
import os
import pathlib

import grpc
from google.protobuf.json_format import MessageToJson

from odsbox.proto import ods_pb2
from odsbox.proto import ods_external_data_pb2 as exd
from odsbox.proto import ods_external_data_pb2_grpc as exd_grpc

# %% [markdown]
# ## EXD-API
#
# The EXD-API plugin is running as a RPC service at a given URL.
# Running `exd_api_server.py`´will run the plugin at the given URL.

# %%
exd_api_plugin_url = "localhost:50051"

# %% [markdown]
# ## Import Phase
#
# We will open a file using the EXD-API and extract the internal structure of the file to import it into the ASAM ODS server.

# %%
data_file_path = os.path.abspath('data/example.tdms')
if not os.path.exists(data_file_path):
    raise Exception('Data file is missing')

# %%
import_file_url = pathlib.Path(data_file_path).as_uri()
import_file_parameters=""
print(import_file_url)

# Will be filled from Structure
access_file_url = None
access_file_parameters = None
# Out:
# file:///workspaces/asam_ods_exd_api_nptdms/data/example.tdms

# %% [markdown]
# ### Extract Infos from Structure
#
# The structure contains infos about groups and channels to create corresponding measurements, submatrices and measurement_quantities

# %%
with grpc.insecure_channel(exd_api_plugin_url) as channel:
    stub = exd_grpc.ExternalDataReaderStub(channel)

    # import file into ASAM ODS Server physical storage
    import_identifier = exd.Identifier(
        url=import_file_url,
        parameters=import_file_parameters)

    import_handle = stub.Open(import_identifier)
    try:
        structure = stub.GetStructure(
            exd.StructureRequest(
                handle=import_handle))
        print(MessageToJson(structure))

        access_file_url = structure.identifier.url
        access_file_parameters = structure.identifier.parameters

        for group in structure.groups:
            group_id = group.id
            for channel in group.channels:
                channel_id = channel.id
    finally:
        stub.Close(import_handle)
# Out:
# {
#   "identifier": {
#     "url": "file:///workspaces/asam_ods_exd_api_nptdms/data/example.tdms"
#   },
#   "name": "example.tdms",
#   "groups": [
#     {
#       "name": "M001A",
#       "totalNumberOfChannels": "3",
#       "numberOfRows": "15",
#       "channels": [
#         {
#           "name": "N",
#           "dataType": "DT_FLOAT",
#           "unitString": "1/min",
#           "attributes": {
#             "variables": {
#               "Average": {
#                 "doubleArray": {
#                   "values": [
#                     1850.0
#                   ]
#                 }
#               },
#               "minimum": {
#                 "doubleArray": {
#                   "values": [
#                     500.0
#                   ]
#                 }
#               },
#               "datatype": {
#                 "stringArray": {
#                   "values": [
#                     "DT_FLOAT"
#                   ]
#                 }
#               },
#               "novaluekey": {
#                 "stringArray": {
#                   "values": [
#                     "No"
#                   ]
#                 }
#               },
#               "displaytype": {
#                 "stringArray": {
#                   "values": [
#                     "Numeric"
#                   ]
#                 }
#               },
#               "description": {
#                 "stringArray": {
#                   "values": [
#                     "Number of revolutions"
#                   ]
#                 }
#               },
#               "MeaQId": {
#                 "longArray": {
#                   "values": [
#                     1
#                   ]
#                 }
#               },
#               "unit_string": {
#                 "stringArray": {
#                   "values": [
#                     "1/min"
#                   ]
#                 }
#               },
#               "MeaQVersion": {
#                 "stringArray": {
#                   "values": [
#                     "D1"
#                   ]
#                 }
#               },
#               "SDeviation": {
#                 "doubleArray": {
#                   "values": [
#                     "NaN"
#                   ]
#                 }
#               },
#               "monotony": {
#                 "stringArray": {
#                   "values": [
#                     "increasing"
#                   ]
#                 }
#               },
#               "maximum": {
#                 "doubleArray": {
#                   "values": [
#                     3200.0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "1",
#           "name": "MD",
#           "dataType": "DT_FLOAT",
#           "unitString": "Nm",
#           "attributes": {
#             "variables": {
#               "Average": {
#                 "doubleArray": {
#                   "values": [
#                     190.0
#                   ]
#                 }
#               },
#               "minimum": {
#                 "doubleArray": {
#                   "values": [
#                     150.0
#                   ]
#                 }
#               },
#               "datatype": {
#                 "stringArray": {
#                   "values": [
#                     "DT_FLOAT"
#                   ]
#                 }
#               },
#               "novaluekey": {
#                 "stringArray": {
#                   "values": [
#                     "No"
#                   ]
#                 }
#               },
#               "displaytype": {
#                 "stringArray": {
#                   "values": [
#                     "Numeric"
#                   ]
#                 }
#               },
#               "description": {
#                 "stringArray": {
#                   "values": [
#                     "Torque"
#                   ]
#                 }
#               },
#               "MeaQId": {
#                 "longArray": {
#                   "values": [
#                     2
#                   ]
#                 }
#               },
#               "unit_string": {
#                 "stringArray": {
#                   "values": [
#                     "Nm"
#                   ]
#                 }
#               },
#               "MeaQVersion": {
#                 "stringArray": {
#                   "values": [
#                     "D"
#                   ]
#                 }
#               },
#               "SDeviation": {
#                 "doubleArray": {
#                   "values": [
#                     22.2
#                   ]
#                 }
#               },
#               "monotony": {
#                 "stringArray": {
#                   "values": [
#                     "not monotone"
#                   ]
#                 }
#               },
#               "maximum": {
#                 "doubleArray": {
#                   "values": [
#                     255.0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "2",
#           "name": "PL",
#           "dataType": "DT_FLOAT",
#           "unitString": "mbar",
#           "attributes": {
#             "variables": {
#               "Average": {
#                 "doubleArray": {
#                   "values": [
#                     992.0
#                   ]
#                 }
#               },
#               "minimum": {
#                 "doubleArray": {
#                   "values": [
#                     987.5999755859375
#                   ]
#                 }
#               },
#               "datatype": {
#                 "stringArray": {
#                   "values": [
#                     "DT_FLOAT"
#                   ]
#                 }
#               },
#               "novaluekey": {
#                 "stringArray": {
#                   "values": [
#                     "No"
#                   ]
#                 }
#               },
#               "displaytype": {
#                 "stringArray": {
#                   "values": [
#                     "Numeric"
#                   ]
#                 }
#               },
#               "description": {
#                 "stringArray": {
#                   "values": [
#                     "Pressure "
#                   ]
#                 }
#               },
#               "MeaQId": {
#                 "longArray": {
#                   "values": [
#                     3
#                   ]
#                 }
#               },
#               "unit_string": {
#                 "stringArray": {
#                   "values": [
#                     "mbar"
#                   ]
#                 }
#               },
#               "MeaQVersion": {
#                 "stringArray": {
#                   "values": [
#                     "D"
#                   ]
#                 }
#               },
#               "SDeviation": {
#                 "doubleArray": {
#                   "values": [
#                     "NaN"
#                   ]
#                 }
#               },
#               "monotony": {
#                 "stringArray": {
#                   "values": [
#                     "not monotone"
#                   ]
#                 }
#               },
#               "maximum": {
#                 "doubleArray": {
#                   "values": [
#                     993.2000122070312
#                   ]
#                 }
#               }
#             }
#           }
#         }
#       ],
#       "attributes": {
#         "variables": {
#           "MeaVersion": {
#             "stringArray": {
#               "values": [
#                 "A1"
#               ]
#             }
#           },
#           "ROZ": {
#             "doubleArray": {
#               "values": [
#                 0.0
#               ]
#             }
#           },
#           "MeaId": {
#             "longArray": {
#               "values": [
#                 1
#               ]
#             }
#           },
#           "MeaComment": {
#             "stringArray": {
#               "values": [
#                 "No Problem"
#               ]
#             }
#           },
#           "description": {
#             "stringArray": {
#               "values": [
#                 "1. Measurement "
#               ]
#             }
#           },
#           "MeasurementEnd": {
#             "stringArray": {
#               "values": [
#                 "19971210152135000000"
#               ]
#             }
#           },
#           "MeasurementBegin": {
#             "stringArray": {
#               "values": [
#                 "19971210131345000000"
#               ]
#             }
#           },
#           "MeaType": {
#             "stringArray": {
#               "values": [
#                 "TLM"
#               ]
#             }
#           },
#           "CreateDate": {
#             "stringArray": {
#               "values": [
#                 "19971210155331000000"
#               ]
#             }
#           }
#         }
#       }
#     },
#     {
#       "id": "1",
#       "name": "M002A",
#       "totalNumberOfChannels": "4",
#       "numberOfRows": "15",
#       "channels": [
#         {
#           "name": "SPTNR",
#           "dataType": "DT_DOUBLE",
#           "unitString": "-",
#           "attributes": {
#             "variables": {
#               "Average": {
#                 "doubleArray": {
#                   "values": [
#                     7.5
#                   ]
#                 }
#               },
#               "minimum": {
#                 "doubleArray": {
#                   "values": [
#                     1.0
#                   ]
#                 }
#               },
#               "datatype": {
#                 "stringArray": {
#                   "values": [
#                     "DT_DOUBLE"
#                   ]
#                 }
#               },
#               "novaluekey": {
#                 "stringArray": {
#                   "values": [
#                     "No"
#                   ]
#                 }
#               },
#               "displaytype": {
#                 "stringArray": {
#                   "values": [
#                     "Numeric"
#                   ]
#                 }
#               },
#               "description": {
#                 "stringArray": {
#                   "values": [
#                     "System point number "
#                   ]
#                 }
#               },
#               "MeaQId": {
#                 "longArray": {
#                   "values": [
#                     4
#                   ]
#                 }
#               },
#               "unit_string": {
#                 "stringArray": {
#                   "values": [
#                     "-"
#                   ]
#                 }
#               },
#               "MeaQVersion": {
#                 "stringArray": {
#                   "values": [
#                     "A"
#                   ]
#                 }
#               },
#               "SDeviation": {
#                 "doubleArray": {
#                   "values": [
#                     "NaN"
#                   ]
#                 }
#               },
#               "monotony": {
#                 "stringArray": {
#                   "values": [
#                     "increasing"
#                   ]
#                 }
#               },
#               "maximum": {
#                 "doubleArray": {
#                   "values": [
#                     15.0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "1",
#           "name": "N",
#           "dataType": "DT_DOUBLE",
#           "unitString": "1/min",
#           "attributes": {
#             "variables": {
#               "Average": {
#                 "doubleArray": {
#                   "values": [
#                     1850.0
#                   ]
#                 }
#               },
#               "minimum": {
#                 "doubleArray": {
#                   "values": [
#                     500.0
#                   ]
#                 }
#               },
#               "datatype": {
#                 "stringArray": {
#                   "values": [
#                     "DT_DOUBLE"
#                   ]
#                 }
#               },
#               "novaluekey": {
#                 "stringArray": {
#                   "values": [
#                     "No"
#                   ]
#                 }
#               },
#               "displaytype": {
#                 "stringArray": {
#                   "values": [
#                     "Numeric"
#                   ]
#                 }
#               },
#               "description": {
#                 "stringArray": {
#                   "values": [
#                     "Revolution "
#                   ]
#                 }
#               },
#               "MeaQId": {
#                 "longArray": {
#                   "values": [
#                     5
#                   ]
#                 }
#               },
#               "unit_string": {
#                 "stringArray": {
#                   "values": [
#                     "1/min"
#                   ]
#                 }
#               },
#               "MeaQVersion": {
#                 "stringArray": {
#                   "values": [
#                     "D"
#                   ]
#                 }
#               },
#               "SDeviation": {
#                 "doubleArray": {
#                   "values": [
#                     "NaN"
#                   ]
#                 }
#               },
#               "monotony": {
#                 "stringArray": {
#                   "values": [
#                     "increasing"
#                   ]
#                 }
#               },
#               "maximum": {
#                 "doubleArray": {
#                   "values": [
#                     3200.0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "2",
#           "name": "MD",
#           "dataType": "DT_DOUBLE",
#           "unitString": "Nm",
#           "attributes": {
#             "variables": {
#               "Average": {
#                 "doubleArray": {
#                   "values": [
#                     194.0
#                   ]
#                 }
#               },
#               "minimum": {
#                 "doubleArray": {
#                   "values": [
#                     150.0
#                   ]
#                 }
#               },
#               "datatype": {
#                 "stringArray": {
#                   "values": [
#                     "DT_DOUBLE"
#                   ]
#                 }
#               },
#               "novaluekey": {
#                 "stringArray": {
#                   "values": [
#                     "No"
#                   ]
#                 }
#               },
#               "displaytype": {
#                 "stringArray": {
#                   "values": [
#                     "Numeric"
#                   ]
#                 }
#               },
#               "description": {
#                 "stringArray": {
#                   "values": [
#                     "Torque "
#                   ]
#                 }
#               },
#               "MeaQId": {
#                 "longArray": {
#                   "values": [
#                     6
#                   ]
#                 }
#               },
#               "unit_string": {
#                 "stringArray": {
#                   "values": [
#                     "Nm"
#                   ]
#                 }
#               },
#               "MeaQVersion": {
#                 "stringArray": {
#                   "values": [
#                     "D"
#                   ]
#                 }
#               },
#               "SDeviation": {
#                 "doubleArray": {
#                   "values": [
#                     "NaN"
#                   ]
#                 }
#               },
#               "monotony": {
#                 "stringArray": {
#                   "values": [
#                     "not monotone"
#                   ]
#                 }
#               },
#               "maximum": {
#                 "doubleArray": {
#                   "values": [
#                     255.0
#                   ]
#                 }
#               }
#             }
#           }
#         },
#         {
#           "id": "3",
#           "name": "TEMP1",
#           "dataType": "DT_DOUBLE",
#           "unitString": "Grd C",
#           "attributes": {
#             "variables": {
#               "Average": {
#                 "doubleArray": {
#                   "values": [
#                     169.0
#                   ]
#                 }
#               },
#               "minimum": {
#                 "doubleArray": {
#                   "values": [
#                     150.0
#                   ]
#                 }
#               },
#               "datatype": {
#                 "stringArray": {
#                   "values": [
#                     "DT_DOUBLE"
#                   ]
#                 }
#               },
#               "novaluekey": {
#                 "stringArray": {
#                   "values": [
#                     "Yes"
#                   ]
#                 }
#               },
#               "displaytype": {
#                 "stringArray": {
#                   "values": [
#                     "Numeric"
#                   ]
#                 }
#               },
#               "description": {
#                 "stringArray": {
#                   "values": [
#                     "Temperature "
#                   ]
#                 }
#               },
#               "MeaQId": {
#                 "longArray": {
#                   "values": [
#                     7
#                   ]
#                 }
#               },
#               "unit_string": {
#                 "stringArray": {
#                   "values": [
#                     "Grd C"
#                   ]
#                 }
#               },
#               "MeaQVersion": {
#                 "stringArray": {
#                   "values": [
#                     "D"
#                   ]
#                 }
#               },
#               "SDeviation": {
#                 "doubleArray": {
#                   "values": [
#                     "NaN"
#                   ]
#                 }
#               },
#               "monotony": {
#                 "stringArray": {
#                   "values": [
#                     "increasing"
#                   ]
#                 }
#               },
#               "maximum": {
#                 "doubleArray": {
#                   "values": [
#                     183.0
#                   ]
#                 }
#               }
#             }
#           }
#         }
#       ],
#       "attributes": {
#         "variables": {
#           "MeaVersion": {
#             "stringArray": {
#               "values": [
#                 "A1"
#               ]
#             }
#           },
#           "ROZ": {
#             "doubleArray": {
#               "values": [
#                 0.0
#               ]
#             }
#           },
#           "MeaId": {
#             "longArray": {
#               "values": [
#                 2
#               ]
#             }
#           },
#           "MeaComment": {
#             "stringArray": {
#               "values": [
#                 "No problem"
#               ]
#             }
#           },
#           "description": {
#             "stringArray": {
#               "values": [
#                 "2. Measurement "
#               ]
#             }
#           },
#           "MeasurementEnd": {
#             "stringArray": {
#               "values": [
#                 "19971211111145000000"
#               ]
#             }
#           },
#           "MeasurementBegin": {
#             "stringArray": {
#               "values": [
#                 "19971211080412000000"
#               ]
#             }
#           },
#           "MeaType": {
#             "stringArray": {
#               "values": [
#                 "VLM"
#               ]
#             }
#           },
#           "CreateDate": {
#             "stringArray": {
#               "values": [
#                 "19971211111522000000"
#               ]
#             }
#           }
#         }
#       }
#     }
#   ],
#   "attributes": {
#     "variables": {
#       "CreateDate": {
#         "stringArray": {
#           "values": [
#             "19971210091422000000"
#           ]
#         }
#       },
#       "name": {
#         "stringArray": {
#           "values": [
#             "Example_ATF_CLA"
#           ]
#         }
#       },
#       "TestVersion": {
#         "stringArray": {
#           "values": [
#             "B20"
#           ]
#         }
#       },
#       "TestId": {
#         "longArray": {
#           "values": [
#             1
#           ]
#         }
#       },
#       "datestring": {
#         "stringArray": {
#           "values": [
#             "10.12.2020"
#           ]
#         }
#       },
#       "title": {
#         "stringArray": {
#           "values": [
#             "---"
#           ]
#         }
#       },
#       "TestType": {
#         "stringArray": {
#           "values": [
#             "Functionality Test"
#           ]
#         }
#       },
#       "description": {
#         "stringArray": {
#           "values": [
#             "The first test of engine 1"
#           ]
#         }
#       },
#       "TestComment": {
#         "stringArray": {
#           "values": [
#             "Test: torque and at special points temperature"
#           ]
#         }
#       },
#       "timestring": {
#         "stringArray": {
#           "values": [
#             "11:59:28"
#           ]
#         }
#       },
#       "exhaust": {
#         "stringArray": {
#           "values": [
#             "System 4711"
#           ]
#         }
#       },
#       "datetime": {
#         "stringArray": {
#           "values": [
#             "20201210105928000000"
#           ]
#         }
#       },
#       "author": {
#         "stringArray": {
#           "values": [
#             "---"
#           ]
#         }
#       },
#       "air_filter": {
#         "stringArray": {
#           "values": [
#             "C 12.1"
#           ]
#         }
#       }
#     }
#   }
# }

# %% [markdown]
# ## Access Bulk Data
#
# With the stored information the ASAM ODS server can access the bulk data from the EXD-API plugin

# %%
with grpc.insecure_channel(exd_api_plugin_url) as channel:
    stub = exd_grpc.ExternalDataReaderStub(channel)

    # info from physical storage
    access_group_id = 0
    access_channel_ids = [0, 1]
    access_identifier = exd.Identifier(
        url=access_file_url,
        parameters=access_file_parameters)

    # open bulk access
    access_handle = stub.Open(access_identifier)
    try:
        request = exd.ValuesRequest(
            handle=access_handle,
            group_id=access_group_id,
            channel_ids=access_channel_ids)

        # read first chunk
        request.start = 0
        request.limit = 3
        values = stub.GetValues(request)
        print(MessageToJson(values))

    finally:
        stub.Close(access_handle)
# Out:
# {
#   "channels": [
#     {
#       "values": {
#         "dataType": "DT_FLOAT",
#         "floatArray": {
#           "values": [
#             500.0,
#             700.0,
#             900.0
#           ]
#         }
#       }
#     },
#     {
#       "id": "1",
#       "values": {
#         "dataType": "DT_FLOAT",
#         "floatArray": {
#           "values": [
#             150.0,
#             160.0,
#             170.0
#           ]
#         }
#       }
#     }
#   ]
# }
